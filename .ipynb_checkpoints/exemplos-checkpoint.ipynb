# %% [markdown]
# # Preparação inicial dos dados

# %%
import pandas as pd

# %%
# Dados de gelolocalização disponível no Kaggle
# https://www.kaggle.com/olistbr/brazilian-ecommerce?select=olist_geolocation_dataset.csv
df = pd.read_csv('olist_geolocation_dataset.csv')

# %%
# Primeiras observações:
df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
# Tipos das variáveis:
df.dtypes
# Out:
# geolocation_zip_code_prefix      int64
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                object
# geolocation_state               object
# dtype: object

# %%
# Dimensões do conjunto de dados:
df.shape
# Out:
# (1000163, 5)

# %%
# Distribuição dos registros por estado:
df.geolocation_state.value_counts()
# Out:
# SP    404268
# MG    126336
# RJ    121169
# RS     61851
# PR     57859
# SC     38328
# BA     36045
# GO     20139
# ES     16748
# PE     16432
# DF     12986
# MT     12031
# CE     11674
# PA     10853
# MS     10431
# MA      7853
# PB      5538
# RN      5041
# PI      4549
# AL      4183
# TO      3576
# SE      3563
# RO      3478
# AM      2432
# AC      1301
# AP       853
# RR       646
# Name: geolocation_state, dtype: int64

# %%
# Arredondamento das coordenadas para 2 casas de precisão (erro aproximado de 1km)
# O objetivo aqui é somente reduzir a quantidade de pontos, após agregá-los
df['geolocation_lat'] = df['geolocation_lat'].round(2)
df['geolocation_lng'] = df['geolocation_lng'].round(2)
df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037           -23.55           -46.64
# 1                         1046           -23.55           -46.64
# 2                         1046           -23.55           -46.64
# 3                         1041           -23.54           -46.64
# 4                         1035           -23.54           -46.64
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
# Agregando os pontos:
df_agg = df.groupby(['geolocation_lat', 'geolocation_lng']).agg(
    uf=('geolocation_state', 'min'),
    n_pontos=('geolocation_lat', 'count')
).reset_index()

# %%
df_agg.head()
# Out:
#    geolocation_lat  geolocation_lng  uf  n_pontos
# 0           -36.61           -64.28  RS         1
# 1           -36.60           -64.29  RS         2
# 2           -34.62           -58.90  BA         1
# 3           -34.59           -58.73  RJ         1
# 4           -33.69           -53.48  RS        10

# %%
df_agg.shape
# Out:
# (55305, 4)

# %%
# Distribuição dos registros aggregados por estado:
df_agg.uf.value_counts()
# Out:
# SP    12009
# MG     7557
# RS     4819
# PR     4348
# RJ     3986
# SC     3840
# BA     2766
# GO     2260
# CE     1385
# MT     1354
# PE     1297
# MA     1156
# PA     1111
# ES     1079
# MS      970
# PI      744
# PB      727
# RN      680
# TO      600
# AL      504
# DF      476
# RO      464
# SE      390
# AM      389
# AC      178
# RR      109
# AP      107
# Name: uf, dtype: int64

# %% [markdown]
# # Garantindo somente dados de AL

# %%
import json
from shapely.geometry import Point, Polygon

# %%
# Como existe a possibilidade do campo UF possuir erros, o objetivo aqui é filtrar AL com base nas coordenadas

# %%
# Download das coordenadas do estado de MG disponível do GitHub:
# https://github.com/eduardo-veras/kml-brasil/tree/master/lib/2010/estados

# %%
with open('AL.json') as json_file:
    data_geo = json.load(json_file)
data_geo
# Out:
# {'state': {'code': 'AL', 'name': 'ALAGOAS', 'region': 'NORDESTE'},
#    {'lat': -8.87181229470157, 'lng': -35.849143349186214},
#    {'lat': -8.87034374676649, 'lng': -35.82574820111851},
#    {'lat': -8.847685126367416, 'lng': -35.79507523813173},
#    {'lat': -8.86358424531663, 'lng': -35.775768909007894},
#    {'lat': -8.897542133162823, 'lng': -35.78298072717881},
#    {'lat': -8.917151719076472, 'lng': -35.74839925841896},
#    {'lat': -8.904798101750927, 'lng': -35.71370147404374},
#    {'lat': -8.89663404182754, 'lng': -35.6712040827022},
#    {'lat': -8.880402254660286, 'lng': -35.65635471090112},
#    {'lat': -8.881278330130765, 'lng': -35.632127760087975},
#    {'lat': -8.835444159920009, 'lng': -35.56748184651},
#    {'lat': -8.819454778714992, 'lng': -35.53517790903318},
#    {'lat': -8.818623522757324, 'lng': -35.50714477191364},
#    {'lat': -8.828302316198883, 'lng': -35.4957536908801},
#    {'lat': -8.81743535016128, 'lng': -35.46752527047484}]]}

# %%
# Converte as coordenadas em data frame:
df_borders = pd.DataFrame(data_geo['borders'][0])
df_borders.head()
# Out:
#         lat        lng
# 0 -8.817435 -35.467525
# 1 -8.842002 -35.449483
# 2 -8.836231 -35.411226
# 3 -8.849836 -35.394571
# 4 -8.876556 -35.287654

# %%
# Cria o polígono do estado de MG:
poligono = zip(list(df_borders.lng), list(df_borders.lat))
poligono = Polygon(poligono)
poligono

# %%
# Função para identificar se um ponto está dentro de um polígono
def within_polygon(lng, lat, polygon):
    point = Point(float(lng), float(lat))
    return point.within(polygon)

# %%
df_agg.head()
# Out:
#    geolocation_lat  geolocation_lng  uf  n_pontos
# 0           -36.61           -64.28  RS         1
# 1           -36.60           -64.29  RS         2
# 2           -34.62           -58.90  BA         1
# 3           -34.59           -58.73  RJ         1
# 4           -33.69           -53.48  RS        10

# %%
# Aplica a função para identificação dos pontos de AL:
df_agg['localizado_no_poligono'] = df_agg.apply(lambda x: within_polygon(
    x.geolocation_lng, x.geolocation_lat, poligono), axis=1)

# %%
df_agg.head()
# Out:
#    geolocation_lat  geolocation_lng  uf  n_pontos  localizado_no_poligono
# 0           -36.61           -64.28  RS         1                   False
# 1           -36.60           -64.29  RS         2                   False
# 2           -34.62           -58.90  BA         1                   False
# 3           -34.59           -58.73  RJ         1                   False
# 4           -33.69           -53.48  RS        10                   False

# %%
# True = localizado no poligono:
df_agg.localizado_no_poligono.value_counts()
# Out:
# False    54812
# True       493
# Name: localizado_no_poligono, dtype: int64

# %%
# Observa-se alguns erros no dataset ao cruzar os dados obtidos pela análise do polígono e a variável UF:
pd.crosstab(df_agg.uf, df_agg.localizado_no_poligono).reset_index()
# Out:
# localizado_no_poligono  uf  False  True
# 0                       AC    178     0
# 1                       AL     14   490
# 2                       AM    389     0
# 3                       AP    107     0
# 4                       BA   2766     0
# 5                       CE   1385     0
# 6                       DF    476     0
# 7                       ES   1079     0
# 8                       GO   2260     0
# 9                       MA   1156     0
# 10                      MG   7557     0
# 11                      MS    970     0
# 12                      MT   1354     0
# 13                      PA   1111     0
# 14                      PB    727     0
# 15                      PE   1296     1
# 16                      PI    744     0
# 17                      PR   4348     0
# 18                      RJ   3985     1
# 19                      RN    680     0
# 20                      RO    464     0
# 21                      RR    109     0
# 22                      RS   4819     0
# 23                      SC   3840     0
# 24                      SE    389     1
# 25                      SP  12009     0
# 26                      TO    600     0

# %%
# Filtra somente os dados de AL (localizado_no_poligono = True)
df_al = df_agg[df_agg.localizado_no_poligono]
df_al.shape
# Out:
# (493, 5)

# %% [markdown]
# # Plotando os pontos no mapa de Alagoas:

# %%
import geopandas as gpd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Necessário fazer o download do shape file no site do IBGE
# https://www.ibge.gov.br/geociencias/organizacao-do-territorio/15774-malhas.html?=&t=downloads

# %%
# Carregando o shape file
shape_path = os.path.join('al_municipios', 'AL_Municipios_2019.shp')
shape_al = gpd.read_file(shape_path)

# %%
shape_al.head()
# Out:
#     CD_MUN                  NM_MUN SIGLA_UF  AREA_KM2  \
# 0  2700102             Água Branca       AL   468.226
# 1  2700201                  Anadia       AL   186.134
# 2  2700300               Arapiraca       AL   345.655
# 3  2700409                 Atalaia       AL   533.258
# 4  2700508  Barra de Santo Antônio       AL   131.364
#
#                                             geometry
# 0  POLYGON ((-37.96166 -9.25007, -37.96173 -9.250...
# 1  POLYGON ((-36.38463 -9.65499, -36.38484 -9.654...
# 2  POLYGON ((-36.73545 -9.73629, -36.75253 -9.710...
# 3  POLYGON ((-36.15554 -9.47280, -36.15551 -9.472...
# 4  POLYGON ((-35.53127 -9.43457, -35.53129 -9.434...

# %%
df_al.head()
# Out:
#        geolocation_lat  geolocation_lng  uf  n_pontos  localizado_no_poligono
# 45990           -10.41           -36.43  AL        14                    True
# 46001           -10.39           -36.38  AL         1                    True
# 46031           -10.35           -36.30  AL         1                    True
# 46071           -10.32           -36.57  SE         1                    True
# 46083           -10.30           -36.58  AL         3                    True

# %%
# Plotando os pontos:
# Não esquecer que x = longitude e y = latitude!!!

# Plotando apenas o mapa:
geometry = [Point(xy) for xy in zip(df_al['geolocation_lng'], df_al['geolocation_lat'])]
fig, ax = plt.subplots(figsize=(15,8))
shape_al.plot(ax=ax, color='#c7c6af')
# Out:
# <AxesSubplot:>

# %%
# Plotando os pontos sobre o mapa:
geometry = [Point(xy) for xy in zip(df_al['geolocation_lng'], df_al['geolocation_lat'])]
fig, ax = plt.subplots(figsize=(15,8))
shape_al.plot(ax=ax, color='#c7c6af')
sns.scatterplot(data=df_al, 
                x='geolocation_lng',
                y='geolocation_lat')
# Out:
# <AxesSubplot:xlabel='geolocation_lng', ylabel='geolocation_lat'>

# %%
# Alterando o tamanho dos pontos em função da variável n_pontos:

geometry = [Point(xy) for xy in zip(df_al['geolocation_lng'], df_al['geolocation_lat'])]
fig, ax = plt.subplots(figsize=(15,8))
shape_al.plot(ax=ax, color='#c7c6af')
sns.scatterplot(data=df_al, 
                x='geolocation_lng',
                y='geolocation_lat',
               )
